# %%
pip install inspyred
# Out:
# Collecting inspyred
#   Downloading inspyred-1.0.1-py2.py3-none-any.whl (88 kB)
#      |████████████████████████████████| 88 kB 4.4 MB/s
# Installing collected packages: inspyred
# Successfully installed inspyred-1.0.1

# %%
from random import Random
from time import time
from math import cos
from math import pi
from inspyred import ec
from inspyred.ec import terminators
import numpy as np
import os

def generate_(random, args): #geração da pop inicial
    size = args.get('num_inputs', 12)
    return [random.randint(0, 16000) for i in range(size)] #max 16000 central
#avaliação da solução
def evaluate_(candidates, args):
    fitness = []
    for cs in candidates: #para cada candidato, gera o fitness, armazena na lista e retorna ela
        fit = perform_fitness(cs[0], cs[1], cs[2], cs[3], cs[4], cs[5], cs[6], cs[7], cs[8], cs[9], cs[10], cs[11])
        fitness.append(fit)
    return fitness
#calcular o fitness para cad individuo
def perform_fitness(carga1_D, carga1_C, carga1_T, carga2_D, carga2_C, carga2_T, carga3_D, carga3_C, carga3_T, carga4_D, carga4_C, carga4_T):
  carga1_D = np.round(carga1_D) #arredondando
  carga1_C = np.round(carga1_C)
  carga1_T = np.round(carga1_T)

  carga2_D = np.round(carga2_D)
  carga2_C = np.round(carga2_C)
  carga2_T = np.round(carga2_T)

  carga3_D = np.round(carga3_D)
  carga3_C = np.round(carga3_C)
  carga3_T = np.round(carga3_T)

  carga4_D = np.round(carga4_D)
  carga4_C = np.round(carga4_C)
  carga4_T = np.round(carga4_T)
#estimativa grosseira
  lucro_total_maximo = 22750
#fitness
  fit = float(((0.31 * carga1_D + 0.31 * carga1_C + 0.31 * carga1_T) +
                (0.38 * carga2_D + 0.38 * carga2_C + 0.38 * carga2_T) + 
                (0.35 * carga3_D + 0.35 * carga3_C + 0.35 * carga3_T) + 
                (0.285 * carga4_D + 0.285 * carga4_C + 0.285 * carga4_T)) / lucro_total_maximo) #dividido pela estimativa grosseira
#restrição de peso dos compartimentos
  h1 = np.maximum(0, float((carga1_D + carga2_D + carga3_D + carga4_D) - 10000)) / float(10000 / 13)  #normalizando, div pela capacidade max dividida pelo fator R
  h2 = np.maximum(0, float((carga1_C + carga2_C + carga3_C + carga4_C) - 16000)) / float(16000 / 13)
  h3 = np.maximum(0, float((carga1_T + carga2_T + carga3_T + carga4_T) - 8000)) / float(8000 / 13)
#restrição  de espaço nos compartimentos
  h4 = np.maximum(0, float((0.48 * carga1_D + 0.65 * carga2_D + 0.58 * carga3_D + 0.39 * carga4_D) - 6800)) / float(6800 / 13)
  h5 = np.maximum(0, float((0.48 * carga1_C + 0.65 * carga2_C + 0.58 * carga3_C + 0.39 * carga4_C) - 8700)) / float(8700 / 13)
  h6 = np.maximum(0, float((0.48 * carga1_T + 0.65 * carga2_T + 0.58 * carga3_T + 0.39 * carga4_T) - 5300)) / float(5300 / 13)

  cargas_total = 34000
  prop_dianteira = float(10000 / cargas_total)
  prop_central = float(16000 / cargas_total)
  prop_traseira = float(8000 / cargas_total)

  carga_dianteira = float(carga1_D + carga2_D + carga3_D + carga4_D)
  carga_central = float(carga1_C + carga2_C + carga3_C + carga4_C)
  carga_traseira = float(carga1_T + carga2_T + carga3_T + carga4_T)
  soma_cargas = float(carga_dianteira + carga_central + carga_traseira)

#proporção
  h7 = np.maximum(0, float(((carga_dianteira / soma_cargas) - prop_dianteira))) / float(prop_dianteira / 13)
  h8 = np.maximum(0, float(((carga_central / soma_cargas) - prop_central))) / float(prop_central / 13)
  h9 = np.maximum(0, float(((carga_traseira / soma_cargas) - prop_traseira))) / float(prop_traseira / 13) 

#restrição do peso max das cargas
  h10 = np.maximum(0, float((carga1_D + carga1_C + carga1_T) - 18000)) / float(18000 / 13)
  h11 = np.maximum(0, float((carga2_D + carga2_C + carga2_T) - 15000)) / float(15000 / 13)
  h12 = np.maximum(0, float((carga3_D + carga3_C + carga3_T) - 23000)) / float(23000 / 13)
  h13 = np.maximum(0, float((carga4_D + carga4_C + carga4_T) - 12000)) / float(12000 / 13)
#fitness obtivo pela solução - penalizações
  fit = fit - (h1 + h2 + h3 + h4 + h5 + h6 + h7 + h8 + h9 + h10 + h11 + h12 + h13)

  return fit


def solution_evaluation(carga1_D, carga1_C, carga1_T, carga2_D, carga2_C, carga2_T, carga3_D, carga3_C, carga3_T, carga4_D, carga4_C, carga4_T):
  carga1_D = np.round(carga1_D)
  carga1_C = np.round(carga1_C)
  carga1_T = np.round(carga1_T)

  carga2_D = np.round(carga2_D)
  carga2_C = np.round(carga2_C)
  carga2_T = np.round(carga2_T)

  carga3_D = np.round(carga3_D)
  carga3_C = np.round(carga3_C)
  carga3_T = np.round(carga3_T)

  carga4_D = np.round(carga4_D)
  carga4_C = np.round(carga4_C)
  carga4_T = np.round(carga4_T)

  print("\n --- Peso por compartimento --- \n")
  print("Carga 1 - dianteira:", carga1_D)
  print("Carga 1 - central:", carga1_C)
  print("Carga 1 - traseira:", carga1_T)
  carga1_total = float(carga1_D + carga1_C + carga1_T)
  print("Carga 1 - Total:", (carga1_total))

  print("\nCarga 2 - dianteira:", carga2_D)
  print("Carga 2 - central:", carga2_C)
  print("Carga 2 - traseira:", carga2_T)
  carga2_total = float(carga2_D + carga2_C + carga2_T)
  print("Carga 2 - Total:", (carga2_total))

  print("\nCarga 3 - dianteira:", carga3_D)
  print("Carga 3 - central:", carga3_C)
  print("Carga 3 - traseira:", carga3_T)
  carga3_total = float(carga3_D + carga3_C + carga3_T)
  print("Carga 3 - Total:", (carga3_total))

  print("\nCarga 4 - dianteira:", carga4_D)
  print("Carga 4 - central:", carga4_C)
  print("Carga 4 - traseira:", carga4_T)
  carga4_total = float(carga4_D + carga4_C + carga4_T)
  print("Carga 4 - Total:", (carga4_total))

  cargas_total = float(carga1_total + carga2_total + carga3_total + carga4_total)

  print("\n Total do peso do carregamento : ", cargas_total)

  print("\nCarga dianteira total:", carga1_D + carga2_D + carga3_D + carga4_D)
  print("Carga central total:", carga1_C + carga2_C + carga3_C + carga4_C)
  print("Carga traseira total:", carga1_T + carga2_T + carga3_T + carga4_T)

  lucro_c1 = float(0.31 * carga1_D + 0.31 * carga1_C + 0.31 * carga1_T)
  lucro_c2 = float(0.38 * carga2_D + 0.38 * carga2_C + 0.38 * carga2_T)
  lucro_c3 = float(0.35 * carga3_D + 0.35 * carga3_C + 0.35 * carga3_T)
  lucro_c4 = float(0.285 * carga4_D + 0.285 * carga4_C + 0.285 * carga4_T)
  
  print("\n --- Lucro por carga --- \n")
  print("Lucro carga 1:", lucro_c1)
  print("Lucro carga 2:", lucro_c2)
  print("Lucro carga 3:", lucro_c3)
  print("Lucro carga 4:", lucro_c4)
  print("Lucro Total :", lucro_c1 + lucro_c2 + lucro_c3 + lucro_c4)

  volume_dianteiro = float((carga1_D * 0.48)+(carga2_D * 0.65) + (carga3_D * 0.58) + (carga4_D * 0.39)) #peso da carga * o volume 
  volume_central = float((carga1_C * 0.48) + (carga2_C * 0.65) + (carga3_C * 0.58) + (carga4_C * 0.39))
  volume_traseiro = float((carga1_T * 0.48)+(carga2_T * 0.65) + (carga3_T * 0.58) + (carga4_T * 0.39))

  print("\n --- Volume por compartimento --- ")
  print("Total de volume dianteiro : ", volume_dianteiro)
  print("Total de volume central : ", volume_central)
  print("Total de volume traseiro : ", volume_traseiro)

  print("\n --- Proporção --- ")
  print("Proporção de Carga Dianteira: ", round(((carga1_D + carga2_D + carga3_D + carga4_D) / cargas_total),4 ))
  print("Proporção de Carga Central: ", round(((carga1_C + carga2_C + carga3_C + carga4_C) / cargas_total),4))
  print("Proporção de Carga Traseira: ", round(((carga1_T + carga2_T + carga3_T + carga4_T) / cargas_total),4))

def main():
  rand = Random()
  rand.seed(int(time())) #inicar semente aleatoria

  ea = ec.GA(rand)
  ea.selector = ec.selectors.tournament_selection #metodo de seleção: torneio
  ea.variator = [ec.variators.uniform_crossover, #op genético crossover uniforme
                  ec.variators.gaussian_mutation] #op genético mutação gaussian_mutation

  ea.replacer = ec.replacers.steady_state_replacement #determina os sobreviventes da prox geração

  ea.terminator = terminators.generation_termination #critério de parada: atingir o máx de geraçoes

  ea.observer = [ec.observers.stats_observer, ec.observers.file_observer] #geração de estatísticas da evolução

  final_pop = ea.evolve(generator=generate_, #gera pop
                        evaluator=evaluate_, #avalia soluções
                        pop_size=10000,
                        maximize=True,
                        bounder=ec.Bounder(0, 16000), #Limites minimos e maximos dos genes
                        max_generations=5000,
                        num_imputs=12,
                        crossover_rate=1.0,
                        num_crossover_points=1,
                        mutation_rate=0.15, #aplicado a cada individuo após crossover
                        num_elites=1, #qts individuos passarão para a prox pop.
                        num_selected=12, #num selecionados do torneio
                        tournament_size=12,
                        statistics_file=open("aviao_stats.csv", "w"),
                        individuals_file=open("aviao_individuais.csv", "w"))

  final_pop.sort(reverse=True) #melhor candidato
  print(final_pop[0])

  perform_fitness(final_pop[0].candidate[0], final_pop[0].candidate[1],final_pop[0].candidate[2],final_pop[0].candidate[3],final_pop[0].candidate[4],final_pop[0].candidate[5],final_pop[0].candidate[6],final_pop[0].candidate[7],final_pop[0].candidate[8],final_pop[0].candidate[9],final_pop[0].candidate[10],final_pop[0].candidate[11])
  solution_evaluation(final_pop[0].candidate[0], final_pop[0].candidate[1], final_pop[0].candidate[2], final_pop[0].candidate[3], final_pop[0].candidate[4], final_pop[0].candidate[5], final_pop[0].candidate[6], final_pop[0].candidate[7], final_pop[0].candidate[8], final_pop[0].candidate[9], final_pop[0].candidate[10], final_pop[0].candidate[11])


main()
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2447      39364 -15.305858 0.43554654 -1.3906367 -1.3504255 0.77229769
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2448      39376 -10.505681 0.43554654 -1.3884631 -1.3471998 0.75982623
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2449      39388 -17.814217 0.43554654 -1.3879390 -1.3488658 0.78631966
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2450      39400 -16.433511 0.43554654 -1.3872780 -1.3469988 0.77990341
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2451      39412 -5.0482004 0.43554654 -1.3858999 -1.3437828 0.75374426
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2452      39424 -6.8698104 0.43554654 -1.3857121 -1.3439417 0.75690940
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2453      39436 -6.9524676 0.43554654 -1.3852697 -1.3436286 0.75821362
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2454      39448 -8.9709922 0.43554654 -1.3851513 -1.3433065 0.75894952
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2455      39460 -2.6062547 0.43554654 -1.3843076 -1.3396199 0.74904544
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2456      39472 -7.2988973 0.43554654 -1.3835301 -1.3393419 0.75272366
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2457      39484 -9.2968995 0.43554654 -1.3827089 -1.3397079 0.75785806
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2458      39496 -9.3355781 0.43554654 -1.3821594 -1.3386005 0.75616351
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2459      39508 -5.5725129 0.43554654 -1.3799926 -1.3360345 0.74869923
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2460      39520 -7.9107074 0.43554654 -1.3772202 -1.3362492 0.75286687
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2461      39532 -7.2268741 0.43554654 -1.3764287 -1.3352260 0.75163881
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2462      39544 -5.2626575 0.43554654 -1.3762184 -1.3340937 0.74781020
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2463      39556 -5.2041701 0.43554654 -1.3755985 -1.3329089 0.74694334
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2464      39568 -11.868054 0.43554654 -1.3751365 -1.3335601 0.75591809
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2465      39580 -12.470728 0.43554654 -1.3750294 -1.3342013 0.76036097
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2466      39592 -6.8139563 0.43554654 -1.3748065 -1.3324656 0.75035017
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2467      39604 -8.4924559 0.43554654 -1.3748065 -1.3329879 0.75401501
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2468      39616 -6.7356139 0.43554654 -1.3742462 -1.3310789 0.74729904
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2469      39628 -9.4345205 0.43554654 -1.3735196 -1.3308731 0.74919615
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2470      39640 -12.658567 0.43554654 -1.3720534 -1.3308036 0.75656854
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2471      39652 -5.1870697 0.43554654 -1.3705395 -1.3273080 0.74363287
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2472      39664 -10.952061 0.43554654 -1.3701587 -1.3289712 0.75527117
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2473      39676 -17.319938 0.43554654 -1.3687595 -1.3307610 0.78725897
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2474      39688 -6.1787894 0.43554654 -1.3685646 -1.3266209 0.74618133
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2475      39700 -6.0965893 0.43554654 -1.3681218 -1.3255919 0.74447966
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2476      39712 -13.063635 0.43554654 -1.3666542 -1.3266918 0.76201153
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2477      39724 -9.1902076 0.43554654 -1.3658319 -1.3253795 0.74939025
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2478      39736 -2.5685336 0.43554654 -1.3647499 -1.3211650 0.73923143
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2479      39748 -6.1017903 0.43554654 -1.3633700 -1.3205580 0.74061917
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2480      39760 -12.852758 0.43554654 -1.3633700 -1.3221384 0.75346598
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2481      39772 -5.8059644 0.43554654 -1.3633700 -1.3205681 0.74161368
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2482      39784 -6.9583401 0.43554654 -1.3633700 -1.3209728 0.74419967
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2483      39796 -10.440601 0.43554654 -1.3626700 -1.3207887 0.74827394
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2484      39808 -5.6227181 0.43554654 -1.3622504 -1.3182646 0.74015431
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2485      39820 -7.8270749 0.43554654 -1.3607783 -1.3171626 0.74194292
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2486      39832 -12.792483 0.43554654 -1.3606044 -1.3191027 0.75724466
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2487      39844 -17.016888 0.43554654 -1.3600954 -1.3182935 0.76185010
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2488      39856 -8.9442395 0.43554654 -1.3595432 -1.3164548 0.74664852
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2489      39868 -6.6334392 0.43554654 -1.3589173 -1.3148509 0.74036200
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2490      39880 -9.6821209 0.43554654 -1.3573362 -1.3150725 0.74779914
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2491      39892 -10.230736 0.43554654 -1.3569943 -1.3142539 0.74617447
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2492      39904 -9.3405676 0.43554654 -1.3554517 -1.3116469 0.73867343
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2493      39916 -16.723535 0.43554654 -1.3553752 -1.3145120 0.76328814
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2494      39928 -14.024340 0.43554654 -1.3545739 -1.3124793 0.75149322
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2495      39940 -15.024802 0.43554654 -1.3542718 -1.3127204 0.75706770
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2496      39952 -8.6253886 0.43554654 -1.3530928 -1.3111845 0.74455745
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2497      39964 -6.7411639 0.43554654 -1.3529878 -1.3109627 0.74202643
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2498      39976 -14.364417 0.43554654 -1.3525951 -1.3109214 0.74994480
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2499      39988 -7.3704373 0.43554654 -1.3521008 -1.3093845 0.74119627
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2500      40000 -9.8480246 0.43554654 -1.3521008 -1.3102862 0.74747673
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2501      40012 -6.2884004 0.43554654 -1.3519551 -1.3073508 0.73441136
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2502      40024 -5.0075171 0.43554654 -1.3517635 -1.3061010 0.73248257
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2503      40036 -3.9626987 0.43554654 -1.3505045 -1.3048772 0.73161435
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2504      40048 -7.7232245 0.43554654 -1.3499904 -1.3046858 0.73429504
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2505      40060 -13.927518 0.43554654 -1.3492098 -1.3048961 0.74433975
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2506      40072 -5.6528080 0.43554654 -1.3491661 -1.3031430 0.73232480
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2507      40084 -10.102079 0.43554654 -1.3482769 -1.3031890 0.73812600
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2508      40096 -9.5868619 0.43554654 -1.3462042 -1.3014214 0.73661543
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2509      40108 -4.6215313 0.43554654 -1.3459396 -1.2999066 0.72998735
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2510      40120 -17.581577 0.43554654 -1.3458295 -1.3028181 0.75975640
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2511      40132 -4.8571337 0.43554654 -1.3453083 -1.2995650 0.73136015
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2512      40144 -5.7668546 0.43554654 -1.3442999 -1.2981831 0.73052398
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2513      40156 -9.5718143 0.43554654 -1.3435414 -1.2987621 0.73904945
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2514      40168 -3.4862438 0.43554654 -1.3417696 -1.2948276 0.72712328
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2515      40180 -9.0904431 0.43554654 -1.3411891 -1.2954641 0.73431594
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2516      40192 -7.2302533 0.43554654 -1.3408866 -1.2947845 0.73286583
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2517      40204 -4.3638386 0.43554654 -1.3406845 -1.2929225 0.72727054
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2518      40216 -7.0056519 0.43554654 -1.3391743 -1.2916645 0.72811673
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2519      40228 -4.3011730 0.43554654 -1.3379899 -1.2902480 0.72599290
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2520      40240 -9.4572597 0.43554654 -1.3376834 -1.2919666 0.73728640
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2521      40252 -16.551467 0.43554654 -1.3366391 -1.2921635 0.75121237
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2522      40264 -8.5265952 0.43554654 -1.3357638 -1.2894470 0.73118652
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2523      40276 -7.4410594 0.43554654 -1.3353526 -1.2884212 0.72791821
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2524      40288 -5.8772196 0.43554654 -1.3337057 -1.2876069 0.72729733
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2525      40300 -11.017934 0.43554654 -1.3327475 -1.2885280 0.73706329
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2526      40312 -18.173100 0.43554654 -1.3318923 -1.2904412 0.77223286
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2527      40324 -8.6546291 0.43554654 -1.3317730 -1.2865222 0.73127958
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2528      40336 -11.067049 0.43554654 -1.3309730 -1.2856377 0.73143305
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2529      40348 -5.4028799 0.43554654 -1.3302114 -1.2836760 0.72327715
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2530      40360 -5.4206237 0.43554654 -1.3302114 -1.2839306 0.72442406
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2531      40372 -9.3468019 0.43554654 -1.3302114 -1.2863941 0.74021951
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2532      40384 -5.6668023 0.43554654 -1.3293180 -1.2818536 0.72232575
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2533      40396 -17.014256 0.43554654 -1.3287534 -1.2835715 0.74311529
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2534      40408 -13.773628 0.43554654 -1.3286998 -1.2832014 0.73881339
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2535      40420 -5.2751641 0.43554654 -1.3281870 -1.2803163 0.72184196
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2536      40432 -6.0990724 0.43554654 -1.3266018 -1.2794130 0.72255513
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2537      40444 -7.3941684 0.43554654 -1.3250322 -1.2790183 0.72348307
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2538      40456 -17.711978 0.43554654 -1.3244250 -1.2808566 0.74649350
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2539      40468 -6.2051472 0.43554654 -1.3231109 -1.2777857 0.72142716
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2540      40480 -9.9237090 0.43554654 -1.3225664 -1.2797429 0.73636990
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2541      40492 -12.548507 0.43554654 -1.3219586 -1.2775897 0.73224731
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2542      40504 -12.150854 0.43554654 -1.3217279 -1.2774092 0.73272966
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2543      40516 -8.8398853 0.43554654 -1.3213617 -1.2755524 0.72372339
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2544      40528 -5.5578576 0.43554654 -1.3210660 -1.2745546 0.71968581
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2545      40540 -10.077483 0.43554654 -1.3189794 -1.2733690 0.72680523
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2546      40552 -8.4615738 0.43554654 -1.3175801 -1.2722830 0.72181535
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2547      40564 -19.089141 0.43554654 -1.3171898 -1.2751459 0.76601835
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2548      40576 -15.002920 0.43554654 -1.3168453 -1.2727810 0.73394827
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2549      40588 -12.872276 0.43554654 -1.3162626 -1.2728109 0.73804375
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2550      40600 -4.9542348 0.43554654 -1.3153936 -1.2686519 0.71552335
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2551      40612 -7.1986520 0.43554654 -1.3139769 -1.2683650 0.71826882
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2552      40624 -7.1361186 0.43554654 -1.3129135 -1.2679908 0.71897063
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2553      40636 -6.6751174 0.43554654 -1.3121811 -1.2678532 0.71973600
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2554      40648 -6.3315803 0.43554654 -1.3118293 -1.2666955 0.71752037
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2555      40660 -9.4234808 0.43554654 -1.3118293 -1.2685871 0.72757995
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2556      40672 -11.553441 0.43554654 -1.3112812 -1.2676245 0.72727258
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2557      40684 -9.8405071 0.43554654 -1.3104001 -1.2651540 0.71967869
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2558      40696 -23.100238 0.43554654 -1.3096730 -1.2668670 0.75593394
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2559      40708 -16.955635 0.43554654 -1.3087262 -1.2661798 0.74179631
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2560      40720 -4.2461294 0.43554654 -1.3068815 -1.2617494 0.71190341
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2561      40732 -10.470512 0.43554654 -1.3066229 -1.2639609 0.72562799
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2562      40744 -5.6898494 0.43554654 -1.3050630 -1.2611163 0.71323709
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2563      40756 -13.068827 0.43554654 -1.3049225 -1.2640386 0.73918652
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2564      40768 -13.817485 0.43554654 -1.3041742 -1.2614450 0.72415406
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2565      40780 -9.9725688 0.43554654 -1.3031457 -1.2597657 0.71739465
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2566      40792 -9.4631146 0.43554654 -1.3030454 -1.2594992 0.71664825
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2567      40804 -7.6107578 0.43554654 -1.3030454 -1.2606810 0.72136899
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2568      40816 -5.0148935 0.43554654 -1.3022696 -1.2577676 0.71048043
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2569      40828 -7.8393176 0.43554654 -1.3020729 -1.2596702 0.72140074
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2570      40840 -11.022685 0.43554654 -1.3004882 -1.2580162 0.72056344
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2571      40852 -7.3469171 0.43554654 -1.3003087 -1.2570595 0.71351262
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2572      40864 -7.1230863 0.43554654 -1.2987203 -1.2556323 0.71244342
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2573      40876 -11.928468 0.43554654 -1.2976869 -1.2557050 0.72046975
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2574      40888 -3.9440220 0.43554654 -1.2959488 -1.2524064 0.70671520
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2575      40900 -4.9631916 0.43554654 -1.2941159 -1.2506769 0.70675128
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2576      40912 -11.435221 0.43554654 -1.2938508 -1.2533003 0.72383324
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2577      40924 -6.3118471 0.43554654 -1.2937699 -1.2506361 0.70950944
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2578      40936 -10.875767 0.43554654 -1.2933184 -1.2499335 0.71292007
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2579      40948 -4.3379993 0.43554654 -1.2923959 -1.2482840 0.70598458
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2580      40960 -10.715699 0.43554654 -1.2920433 -1.2500066 0.71872395
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2581      40972 -13.546695 0.43554654 -1.2919916 -1.2499038 0.72347112
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2582      40984 -7.4252164 0.43554654 -1.2912089 -1.2472139 0.70841080
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2583      40996 -5.3352970 0.43554654 -1.2903830 -1.2461422 0.70683801
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2584      41008 -5.3888707 0.43554654 -1.2903830 -1.2458101 0.70585506
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2585      41020 -9.8403011 0.43554654 -1.2903830 -1.2465920 0.71199335
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2586      41032 -8.3143869 0.43554654 -1.2901765 -1.2470083 0.71475516
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2587      41044 -12.825447 0.43554654 -1.2901765 -1.2477496 0.72561390
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2588      41056 -8.5950330 0.43554654 -1.2900591 -1.2461224 0.71503676
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2589      41068 -6.5831350 0.43554654 -1.2890640 -1.2439644 0.70614634
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2590      41080 -7.5397433 0.43554654 -1.2888062 -1.2429087 0.70516003
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2591      41092 -7.4140908 0.43554654 -1.2880970 -1.2430523 0.70795499
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2592      41104 -7.7407226 0.43554654 -1.2875987 -1.2426847 0.70789638
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2593      41116 -6.2468527 0.43554654 -1.2866454 -1.2414052 0.70503103
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2594      41128 -9.6158868 0.43554654 -1.2859238 -1.2425591 0.71616803
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2595      41140 -8.3060037 0.43554654 -1.2856742 -1.2411298 0.70673666
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2596      41152 -10.735373 0.43554654 -1.2848252 -1.2415141 0.71609401
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2597      41164 -12.075968 0.43554654 -1.2842884 -1.2417211 0.71974608
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2598      41176 -3.4760785 0.43554654 -1.2839578 -1.2377685 0.69990241
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2599      41188 -8.3582074 0.43554654 -1.2837925 -1.2396042 0.71106363
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2600      41200 -7.8627253 0.43554654 -1.2835253 -1.2378699 0.70353781
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2601      41212 -11.065800 0.43554654 -1.2817402 -1.2371686 0.70769678
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2602      41224 -13.128505 0.43554654 -1.2810032 -1.2390726 0.72383495
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2603      41236 -13.696388 0.43554654 -1.2808773 -1.2377534 0.72026618
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2604      41248 -9.3639043 0.43554654 -1.2808041 -1.2366087 0.70972647
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2605      41260 -20.866797 0.43554654 -1.2806951 -1.2372838 0.73088103
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2606      41272 -10.255571 0.43554654 -1.2805688 -1.2368493 0.71313460
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2607      41284 -6.8336363 0.43554654 -1.2790905 -1.2333490 0.69960170
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2608      41296 -11.141599 0.43554654 -1.2782623 -1.2329158 0.70393244
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2609      41308 -6.7051746 0.43554654 -1.2775220 -1.2321452 0.70095803
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2610      41320 -10.714782 0.43554654 -1.2770452 -1.2335317 0.71390299
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2611      41332 -8.9585550 0.43554654 -1.2770452 -1.2325179 0.70687408
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2612      41344 -5.3067996 0.43554654 -1.2756749 -1.2296234 0.69770079
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2613      41356 -6.8505153 0.43554654 -1.2751159 -1.2296304 0.69970744
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2614      41368 -9.8019209 0.43554654 -1.2747403 -1.2295690 0.70471098
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2615      41380 -11.015142 0.43554654 -1.2744364 -1.2300428 0.71082688
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2616      41392 -14.358370 0.43554654 -1.2744364 -1.2306128 0.71634700
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2617      41404 -11.003535 0.43554654 -1.2738410 -1.2280682 0.70210972
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2618      41416 -12.341231 0.43554654 -1.2737316 -1.2301276 0.72068791
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2619      41428 -6.4088998 0.43554654 -1.2727202 -1.2264543 0.69594747
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2620      41440 -7.2527753 0.43554654 -1.2726656 -1.2268253 0.69914760
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2621      41452 -8.3642339 0.43554654 -1.2709196 -1.2252782 0.69781693
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2622      41464 -9.0882834 0.43554654 -1.2705482 -1.2267616 0.70752563
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2623      41476 -5.9705927 0.43554654 -1.2703814 -1.2251189 0.69755333
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2624      41488 -4.9962252 0.43554654 -1.2691887 -1.2235194 0.69406014
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2625      41500 -10.958085 0.43554654 -1.2691887 -1.2259467 0.70881546
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2626      41512 -10.609565 0.43554654 -1.2683223 -1.2234248 0.69866197
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2627      41524 -9.5670630 0.43554654 -1.2673682 -1.2227540 0.69875296
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2628      41536 -9.8991357 0.43554654 -1.2670233 -1.2223022 0.69829717
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2629      41548 -8.2871451 0.43554654 -1.2670233 -1.2225584 0.69847483
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2630      41560 -16.668862 0.43554654 -1.2665121 -1.2238092 0.72430187
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2631      41572 -7.5313734 0.43554654 -1.2656872 -1.2206978 0.69606716
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2632      41584 -7.5670406 0.43554654 -1.2642606 -1.2198180 0.69411970
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2633      41596 -4.3959854 0.43554654 -1.2637736 -1.2183165 0.68995543
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2634      41608 -9.1117936 0.43554654 -1.2627192 -1.2177046 0.69330266
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2635      41620 -9.3619983 0.43554654 -1.2623274 -1.2193374 0.70462763
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2636      41632 -15.573967 0.43554654 -1.2608325 -1.2178646 0.70556825
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2637      41644 -4.5345325 0.43554654 -1.2595162 -1.2147335 0.68764850
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2638      41656 -4.4043119 0.43554654 -1.2583791 -1.2136752 0.68764840
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2639      41668 -7.6683960 0.43554654 -1.2581236 -1.2138971 0.69158406
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2640      41680 -10.685125 0.43554654 -1.2574234 -1.2142301 0.69974532
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2641      41692 -10.380449 0.43554654 -1.2574234 -1.2133196 0.69714126
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2642      41704 -12.953504 0.43554654 -1.2569661 -1.2146308 0.70995441
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2643      41716 -9.6152809 0.43554654 -1.2566740 -1.2147184 0.70688705
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2644      41728 -14.631236 0.43554654 -1.2555295 -1.2137808 0.71245466
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2645      41740 -7.7162324 0.43554654 -1.2552856 -1.2117831 0.69387642
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2646      41752 -9.2580288 0.43554654 -1.2551203 -1.2124889 0.69939586
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2647      41764 -9.3914965 0.43554654 -1.2550133 -1.2112873 0.69453424
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2648      41776 -5.1118128 0.43554654 -1.2545768 -1.2088886 0.68524023
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2649      41788 -7.9861205 0.43554654 -1.2538028 -1.2087232 0.69035956
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2650      41800 -9.5401284 0.43554654 -1.2528202 -1.2098174 0.69994022
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2651      41812 -14.923750 0.43554654 -1.2516695 -1.2082134 0.70170368
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       2652      41824 -6.4571387 0.43554654 -1.2516695 -1.2064102 0.68533617
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ...
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3628      53536 -8.6322625 0.43554654 -0.8239834 -0.7849774 0.49748905
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3629      53548 -6.6484119 0.43554654 -0.8230814 -0.7831856 0.49009719
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3630      53560 -7.2695331 0.43554654 -0.8230814 -0.7844439 0.49791729
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3631      53572 -10.826065 0.43554654 -0.8230814 -0.7847315 0.50217834
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3632      53584 -4.1185603 0.43554654 -0.8229300 -0.7825365 0.48710565
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3633      53596 -10.100198 0.43554654 -0.8228019 -0.7851903 0.50991048
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3634      53608 -7.2773911 0.43554654 -0.8228019 -0.7833066 0.49235040
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3635      53620 -11.110678 0.43554654 -0.8228019 -0.7845751 0.50769479
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3636      53632 -13.440507 0.43554654 -0.8226441 -0.7851344 0.51495856
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3637      53644 -7.2928400 0.43554654 -0.8226441 -0.7836012 0.49734231
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3638      53656 -3.5346458 0.43554654 -0.8225468 -0.7817419 0.48617614
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3639      53668 -9.7065283 0.43554654 -0.8225468 -0.7848518 0.50802547
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3640      53680 -7.2763040 0.43554654 -0.8221054 -0.7827172 0.49603959
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3641      53692 -8.2725092 0.43554654 -0.8221054 -0.7831651 0.49941580
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3642      53704 -13.396929 0.43554654 -0.8221054 -0.7849971 0.52276049
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3643      53716 -3.4273952 0.43554654 -0.8216477 -0.7803923 0.48500813
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3644      53728 -4.4381236 0.43554654 -0.8214539 -0.7807369 0.48799042
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3645      53740 -7.6110735 0.43554654 -0.8210860 -0.7804863 0.49158528
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3646      53752 -8.2527108 0.43554654 -0.8209029 -0.7818136 0.50160094
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3647      53764 -8.6832077 0.43554654 -0.8208162 -0.7809696 0.49737399
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3648      53776 -10.710984 0.43554654 -0.8208162 -0.7825300 0.51313079
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3649      53788 -9.0624863 0.43554654 -0.8200945 -0.7791875 0.49183183
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3650      53800 -6.2889168 0.43554654 -0.8191754 -0.7777574 0.48544812
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3651      53812 -8.9626872 0.43554654 -0.8191754 -0.7799974 0.49906318
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3652      53824 -12.206502 0.43554654 -0.8187043 -0.7804958 0.51199487
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3653      53836 -5.1149500 0.43554654 -0.8180898 -0.7767961 0.48448090
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3654      53848 -10.971753 0.43554654 -0.8180898 -0.7802784 0.50946646
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3655      53860 -8.8173544 0.43554654 -0.8180159 -0.7775024 0.49269276
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3656      53872 -4.9066429 0.43554654 -0.8177463 -0.7770882 0.48675911
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3657      53884 -11.306435 0.43554654 -0.8171101 -0.7778326 0.50076491
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3658      53896 -6.9045141 0.43554654 -0.8171101 -0.7786517 0.49928108
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3659      53908 -8.8199874 0.43554654 -0.8168684 -0.7774627 0.49554085
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3660      53920 -9.1328377 0.43554654 -0.8164320 -0.7772575 0.49926969
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3661      53932 -13.270138 0.43554654 -0.8161941 -0.7777333 0.51294393
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3662      53944 -10.102099 0.43554654 -0.8157660 -0.7761841 0.49742545
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3663      53956 -11.724126 0.43554654 -0.8157660 -0.7780016 0.51550515
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3664      53968 -12.276776 0.43554654 -0.8157660 -0.7770182 0.50532840
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3665      53980 -2.0713792 0.43554654 -0.8151806 -0.7731163 0.48020523
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3666      53992 -9.8351863 0.43554654 -0.8145867 -0.7752427 0.49931454
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3667      54004 -5.1964455 0.43554654 -0.8141899 -0.7732185 0.48348548
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3668      54016 -5.8413560 0.43554654 -0.8141899 -0.7739228 0.48688406
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3669      54028 -10.713276 0.43554654 -0.8136144 -0.7750719 0.50621487
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3670      54040 -20.996031 0.43554654 -0.8136144 -0.7765697 0.55562417
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3671      54052 -15.918613 0.43554654 -0.8135153 -0.7744831 0.51029772
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3672      54064 -16.681739 0.43554654 -0.8135153 -0.7742454 0.51379967
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3673      54076 -8.1448591 0.43554654 -0.8128713 -0.7735858 0.49624051
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3674      54088 -11.023706 0.43554654 -0.8124991 -0.7732569 0.49668004
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3675      54100 -7.6296271 0.43554654 -0.8124053 -0.7735722 0.49634744
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3676      54112 -16.984294 0.43554654 -0.8123047 -0.7751313 0.53645343
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3677      54124 -16.445749 0.43554654 -0.8120000 -0.7758561 0.53764274
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3678      54136 -8.9702394 0.43554654 -0.8114869 -0.7719299 0.49307969
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3679      54148 -8.6633938 0.43554654 -0.8113689 -0.7723722 0.49521515
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3680      54160 -10.200637 0.43554654 -0.8112329 -0.7739115 0.51267885
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3681      54172 -8.2833284 0.43554654 -0.8112329 -0.7717074 0.49364545
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3682      54184 -8.2411603 0.43554654 -0.8105625 -0.7708583 0.49040874
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3683      54196 -4.9407393 0.43554654 -0.8102237 -0.7693997 0.48161275
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3684      54208 -7.8731672 0.43554654 -0.8098476 -0.7711546 0.49735135
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3685      54220 -9.4257853 0.43554654 -0.8097946 -0.7698935 0.48948295
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3686      54232 -14.420902 0.43554654 -0.8097946 -0.7734789 0.53315917
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3687      54244 -5.7532872 0.43554654 -0.8091401 -0.7684117 0.48096584
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3688      54256 -8.8315372 0.43554654 -0.8089360 -0.7705852 0.50071202
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3689      54268 -7.0686577 0.43554654 -0.8087422 -0.7685735 0.48511937
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3690      54280 -9.8476993 0.43554654 -0.8083259 -0.7685970 0.49229042
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3691      54292 -8.6449229 0.43554654 -0.8082201 -0.7687164 0.49074734
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3692      54304 -9.4399091 0.43554654 -0.8080081 -0.7691494 0.49755264
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3693      54316 -11.642051 0.43554654 -0.8080081 -0.7692321 0.49951159
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3694      54328 -14.483908 0.43554654 -0.8073474 -0.7681658 0.50698866
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3695      54340 -9.4576439 0.43554654 -0.8071758 -0.7681700 0.49485026
#
# Generation Evaluation      Worst       Best     Median    Average    Std Dev
# ---------- ---------- ---------- ---------- ---------- ---------- ----------
#       3696      54352 -11.802575 0.43554654 -0.8071758 -0.7695409 0.50923199
